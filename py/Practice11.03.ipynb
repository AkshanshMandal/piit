# %%
student={
    "name" : "Akshansh",
    "age" : 36,
    "major" : "Data Science"
}

# %%
student
# Out:
# {'name': 'Akshansh', 'age': 36, 'major': 'Data Science'}

# %%
student["name"]
# Out:
# 'Akshansh'

# %%
student["gpa"]=3.75

# %%
student
# Out:
# {'name': 'Akshansh', 'age': 36, 'major': 'Data Science', 'gpa': 3.75}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'major', 'gpa'])

# %%
student.values()
# Out:
# dict_values(['Akshansh', 36, 'Data Science', 3.75])

# %%
list(range(5,10,2))
# Out:
# [5, 7, 9]
