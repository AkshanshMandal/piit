# %%
# Install libraries in not availabl
import pandas as pd
import numpy as np

# %%
from pydataset import data

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
dataset_ids = data()['dataset_id'].tolist()
# Join into a comma-separated string
dataset_ids_str = ", ".join(dataset_ids)
print(dataset_ids_str)
# Out:
# AirPassengers, BJsales, BOD, Formaldehyde, HairEyeColor, InsectSprays, JohnsonJohnson, LakeHuron, LifeCycleSavings, Nile, OrchardSprays, PlantGrowth, Puromycin, Titanic, ToothGrowth, UCBAdmissions, UKDriverDeaths, UKgas, USAccDeaths, USArrests, USJudgeRatings, USPersonalExpenditure, VADeaths, WWWusage, WorldPhones, airmiles, airquality, anscombe, attenu, attitude, austres, cars, chickwts, co2, crimtab, discoveries, esoph, euro, faithful, freeny, infert, iris, islands, lh, longley, lynx, morley, mtcars, nhtemp, nottem, npk, occupationalStatus, precip, presidents, pressure, quakes, randu, rivers, rock, sleep, stackloss, sunspot.month, sunspot.year, sunspots, swiss, treering, trees, uspop, volcano, warpbreaks, women, acme, aids, aircondit, aircondit7, amis, aml, bigcity, brambles, breslow, calcium, cane, capability, catsM, cav, cd4, channing, city, claridge, cloth, co.transfer, coal, darwin, dogs, downs.bc, ducks, fir, frets, grav, gravity, hirose, islay, manaus, melanoma, motor, neuro,
# ...

# %%
airquality= data('airquality')
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 1   41.0    190.0   7.4    67      5    1
# 2   36.0    118.0   8.0    72      5    2
# 3   12.0    149.0  12.6    74      5    3
# 4   18.0    313.0  11.5    62      5    4
# 5    NaN      NaN  14.3    56      5    5

# %%
airquality.shape
# Out:
# (153, 6)

# %%
airquality.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
airquality.max()
# Out:
# Ozone      168.0
# Solar.R    334.0
# Wind        20.7
# Temp        97.0
# Month        9.0
# Day         31.0
# dtype: float64

# %%
airquality.min()
# Out:
# Ozone       1.0
# Solar.R     7.0
# Wind        1.7
# Temp       56.0
# Month       5.0
# Day         1.0
# dtype: float64

# %%
airquality.tail(10)
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 144   13.0    238.0  12.6    64      9   21
# 145   23.0     14.0   9.2    71      9   22
# 146   36.0    139.0  10.3    81      9   23
# 147    7.0     49.0  10.3    69      9   24
# 148   14.0     20.0  16.6    63      9   25
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30

# %%
airquality.iloc[5:10]
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 6    28.0      NaN  14.9    66      5    6
# 7    23.0    299.0   8.6    65      5    7
# 8    19.0     99.0  13.8    59      5    8
# 9     8.0     19.0  20.1    61      5    9
# 10    NaN    194.0   8.6    69      5   10

# %%
airquality.isnull().head()
# Out:
#    Ozone  Solar.R   Wind   Temp  Month    Day
# 1  False    False  False  False  False  False
# 2  False    False  False  False  False  False
# 3  False    False  False  False  False  False
# 4  False    False  False  False  False  False
# 5   True     True  False  False  False  False

# %%
airquality.isnull().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
airquality.isnull().sum().sum()
# Out:
# np.int64(44)

# %%
airquality.notnull().head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month   Day
# 1   True     True  True  True   True  True
# 2   True     True  True  True   True  True
# 3   True     True  True  True   True  True
# 4   True     True  True  True   True  True
# 5  False    False  True  True   True  True

# %%
airquality.notnull().sum()
# Out:
# Ozone      116
# Solar.R    146
# Wind       153
# Temp       153
# Month      153
# Day        153
# dtype: int64

# %%
airquality.notnull().sum().sum()
# Out:
# np.int64(874)

# %%
airquality.duplicated().head()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
airquality.duplicated().sum()
# Out:
# np.int64(0)

# %%
airquality[['Ozone','Solar.R']].head()
# Out:
#    Ozone  Solar.R
# 1   41.0    190.0
# 2   36.0    118.0
# 3   12.0    149.0
# 4   18.0    313.0
# 5    NaN      NaN

# %%
airquality.loc[1]
# Out:
# Ozone       41.0
# Solar.R    190.0
# Wind         7.4
# Temp        67.0
# Month        5.0
# Day          1.0
# Name: 1, dtype: float64

# %%
airquality1=airquality.reset_index().rename(columns={'index':'SN'})

# %%
airquality1.head()
# Out:
#    SN  Ozone  Solar.R  Wind  Temp  Month  Day
# 0   1   41.0    190.0   7.4    67      5    1
# 1   2   36.0    118.0   8.0    72      5    2
# 2   3   12.0    149.0  12.6    74      5    3
# 3   4   18.0    313.0  11.5    62      5    4
# 4   5    NaN      NaN  14.3    56      5    5

# %%
airquality.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
airquality.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp         int64
# Month        int64
# Day          int64
# dtype: object

# %%
airquality.nunique
# Out:
# <bound method DataFrame.nunique of      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# 6     28.0      NaN  14.9    66      5    6
# 7     23.0    299.0   8.6    65      5    7
# 8     19.0     99.0  13.8    59      5    8
# 9      8.0     19.0  20.1    61      5    9
# 10     NaN    194.0   8.6    69      5   10
# 11     7.0      NaN   6.9    74      5   11
# 12    16.0    256.0   9.7    69      5   12
# 13    11.0    290.0   9.2    66      5   13
# 14    14.0    274.0  10.9    68      5   14
# 15    18.0     65.0  13.2    58      5   15
# 16    14.0    334.0  11.5    64      5   16
# 17    34.0    307.0  12.0    66      5   17
# 18     6.0     78.0  18.4    57      5   18
# 19    30.0    322.0  11.5    68      5   19
# ...

# %%
airquality['Ozone'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 1       41.0
# 2       36.0
# 3       12.0
# 4       18.0
# 5        NaN
# 6       28.0
# 7       23.0
# 8       19.0
# 9        8.0
# 10       NaN
# 11       7.0
# 12      16.0
# 13      11.0
# 14      14.0
# 15      18.0
# 16      14.0
# 17      34.0
# 18       6.0
# 19      30.0
# 20      11.0
# 21       1.0
# 22      11.0
# 23       4.0
# 24      32.0
# 25       NaN
# 26       NaN
# 27       NaN
# 28      23.0
# 29      45.0
# 30     115.0
# 31      37.0
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38      29.0
# 39       NaN
# 40      71.0
# 41      39.0
# 42       NaN
# 43       NaN
# 44      23.0
# 45       NaN
# 46       NaN
# 47      21.0
# 48      37.0
# 49      20.0
# 50      12.0
# 51      13.0
# 52       NaN
# 53       NaN
# 54       NaN
# 55       NaN
# 56       NaN
# 57       NaN
# 58       NaN
# 59       NaN
# 60       NaN
# 61       NaN
# 62     135.0
# 63      49.0
# 64      32.0
# ...

# %%
airquality.sort_values(by=['Ozone','Temp'],ascending=[False,True]).head()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 117  168.0    238.0   3.4    81      8   25
# 62   135.0    269.0   4.1    84      7    1
# 99   122.0    255.0   4.0    89      8    7
# 121  118.0    225.0   2.3    94      8   29
# 30   115.0    223.0   5.7    79      5   30

# %%
airquality_sorted = airquality.sort_values(by=['Ozone', 'Temp'], ascending=[False, True])
print((airquality_sorted).head())
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 117  168.0    238.0   3.4    81      8   25
# 62   135.0    269.0   4.1    84      7    1
# 99   122.0    255.0   4.0    89      8    7
# 121  118.0    225.0   2.3    94      8   29
# 30   115.0    223.0   5.7    79      5   30
